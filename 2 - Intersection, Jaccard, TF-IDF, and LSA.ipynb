# %% [markdown]
# # 유사곡 추천 101 - 2. 교집합, 자카드 지수, TF-IDF
#
# [블로그](https://blog2.lucent.me/ml/music-recommender-systems-101-intro)에서 다루었던 첫 번째 방법인 교집합과, 교집합의 문제를 해결하는 두 가지 방법인 자카드 지수와 TF-IDF를 살펴봅시다.
# <div style="max-height: 416px;list-style:none !important"><ol class="toc-item"><li><a href="#데이터-로드">데이터 로드</a></li><li><a href="#교집합의-크기">교집합의 크기</a><ul style="margin:0"><li><a href="#가장-큰-k개의-교집합-쿼리">가장 큰 k개의 교집합 쿼리</a></li></ul></li><li><a href="#자카드-지수">자카드 지수</a><ul style="margin:0"><li><a href="#자카드-지수-쿼리">자카드 지수 쿼리</a></li></ul></li><li><a href="#TF-IDF">TF-IDF</a><ul style="margin:0"><li><a href="#TF-IDF-쿼리">TF-IDF 쿼리</a></li></ul></li><li><a href="#Latent-Semantic-Analysis">Latent Semantic Analysis</a><ul style="margin:0"><li><a href="#LSA-쿼리">LSA 쿼리</a></li></ul></li></ol></div>

# %% [markdown]
# ### 데이터 로드
#
# [저번](https://github.com/kcy1019/MusicRecSys-101/blob/master/01%20-%20Getting%20the%20Dataset.ipynb)에 저장한 데이터를 읽어 봅시다.

# %%
import scipy.sparse as sparse
import pandas as pd
import numpy as np

# %%
play_count_matrix = sparse.load_npz('play_count_matrix.npz')
metadata = pd.read_hdf('metadata.hdf', key='data')

# %% [markdown]
# ## 교집합의 크기
#
# 두 노래를 모두 들어본 사람의 수를 구하기 위해서는 먼저 '어떤 노래를 들어본 적 있는가? -> 1, 그렇지 않으면 -> 0' 과 같은 형태로
# 플레이 카운트 행렬을 이진화 해야 합니다.
#
# 이진화를 하고 나면, 간단하게 X * X.T를 수행함으로써 두 노래를 모두 들어본 사람의 수를 계산할 수 있습니다.

# %%
# 이진화
play_count_binary = play_count_matrix.copy().tocsr()
play_count_binary[play_count_binary > 0] = 1
# 교집합 계산
all_pair_intersections = (play_count_binary * play_count_binary.transpose())
all_pair_intersections = np.array(all_pair_intersections.todense())
all_pair_intersections.shape
# Out:
# (10000, 10000)

# %% [markdown]
# ### 가장 큰 k개의 교집합 쿼리

# %%
def query_intersection(song_name, return_k=10):
    idx = metadata[metadata.title == song_name].song.cat.codes.values[0]
    cand = all_pair_intersections[idx].argsort()[::-1][:return_k+1]
    cand = list(cand[cand != idx][:return_k])
    return [idx] + cand  # 맨 위에는 쿼리의 대상이 된 곡을 넣어줍니다.

# %%
metadata.loc[query_intersection('You Belong With Me')]
# Out:
#                    track                song                       artist  \
# code
# 7330  TRJPXVB128F9316916  SOSROFB12AAF3B4C5D                 Taylor Swift
# 7761  TRSDRPY128F933E202  SOTWSXL12A8C143349                 Taylor Swift
# 7761  TROPUMP128F92EC162  SOTWSXL12A8C143349                 Taylor Swift
# 5509  TROAQBZ128F9326213  SONYKOW12AB01849C9                  OneRepublic
# 4414  TRVSBTV12903CC6670  SOLFXKT12AB017E3E0           Charttraxx Karaoke
# 355   TRHKJNX12903CEFCDF  SOAXGDH12A8C13F8A1       Florence + The Machine
# 8567  TRIEXMF128F92FDD60  SOWCKVR12A8C142411                Kings Of Leon
# 8567  TRTEHXL128F931687B  SOWCKVR12A8C142411                Kings Of Leon
# 620   TRCPAGR128F423A01A  SOBOAFP12A8C131F36  Jason Mraz & Colbie Caillat
# 8065  TRSLDDC12903CC36E7  SOUSMXX12AB0185C24    Usher featuring will.i.am
# 4254  TRCBRTN12903CC4BD1  SOKUPAO12AB018D576                     Paramore
# 7395  TRONYHY128F92C9D11  SOSXLTC12AF72A7F54                Kings Of Leon
# 6216  TROHFJK12903CC4BCE  SOPTLQL12AB018D56F                 Travie McCoy
#
#                                                   title                style  \
# code
# 7330                                 You Belong With Me  Country_Traditional
# 7761                                         Love Story                  NaN
# 7761                                         Love Story  Country_Traditional
# 5509                                            Secrets    Rock_Contemporary
# 4414                                          Fireflies                  NaN
# 355                      Dog Days Are Over (Radio Edit)                  NaN
# 8567                                       Use Somebody                  NaN
# 8567                                       Use Somebody                  NaN
# 620                               Lucky (Album Version)                  NaN
# 8065                                                OMG                  NaN
# 4254                 The Only Exception (Album Version)                  NaN
# 7395                                            Revelry         Rock_College
# 6216  Billionaire [feat. Bruno Mars]  (Explicit Albu...                  NaN
#
#          genre
# code
# 7330   Country
# 7761       NaN
# 7761   Country
# 5509  Pop_Rock
# 4414       NaN
# 355        NaN
# 8567  Pop_Rock
# 8567       NaN
# 620        NaN
# 8065       NaN
# 4254       NaN
# 7395  Pop_Rock
# 6216       NaN

# %%
metadata.loc[query_intersection('Fix You')]
# Out:
#                    track                song                       artist  \
# code
# 8597  TRYVBMA128E0789D39  SOWEJXA12A6701C574                     Coldplay
# 1125  TRENTGL128E0780C8E  SOCVTLJ12A6310F0FD                     Coldplay
# 4114  TRQFXKD128E0780CAE  SOKLRPJ12A8C13C3FE                     Coldplay
# 6284  TRIKGRK128E0780DB0  SOPXKYD12A6D4FA876                     Coldplay
# 6284  TRTZNQZ12903CD044C  SOPXKYD12A6D4FA876                     Coldplay
# 5509  TROAQBZ128F9326213  SONYKOW12AB01849C9                  OneRepublic
# 355   TRHKJNX12903CEFCDF  SOAXGDH12A8C13F8A1       Florence + The Machine
# 8567  TRIEXMF128F92FDD60  SOWCKVR12A8C142411                Kings Of Leon
# 8567  TRTEHXL128F931687B  SOWCKVR12A8C142411                Kings Of Leon
# 4414  TRVSBTV12903CC6670  SOLFXKT12AB017E3E0           Charttraxx Karaoke
# 7395  TRONYHY128F92C9D11  SOSXLTC12AF72A7F54                Kings Of Leon
# 620   TRCPAGR128F423A01A  SOBOAFP12A8C131F36  Jason Mraz & Colbie Caillat
# 4254  TRCBRTN12903CC4BD1  SOKUPAO12AB018D576                     Paramore
#
#                                    title              style     genre
# code
# 8597                             Fix You                NaN       NaN
# 1125                              Clocks       Rock_College  Pop_Rock
# 4114                       The Scientist   Pop_Contemporary  Pop_Rock
# 6284                              Yellow   Pop_Contemporary  Pop_Rock
# 6284                              Yellow                NaN       NaN
# 5509                             Secrets  Rock_Contemporary  Pop_Rock
# 355       Dog Days Are Over (Radio Edit)                NaN       NaN
# 8567                        Use Somebody                NaN  Pop_Rock
# 8567                        Use Somebody                NaN       NaN
# 4414                           Fireflies                NaN       NaN
# 7395                             Revelry       Rock_College  Pop_Rock
# 620                Lucky (Album Version)                NaN       NaN
# 4254  The Only Exception (Album Version)                NaN       NaN

# %%
metadata.loc[query_intersection('Welcome To The Black Parade (Album Version)')]
# Out:
#                    track                song                  artist  \
# code
# 6562  TRKJHNE128F42380FC  SOQQAAQ12A67ADE34D     My Chemical Romance
# 4714  TRYZMOC128F423E58D  SOLXXZI12A8AE4733A     My Chemical Romance
# 5509  TROAQBZ128F9326213  SONYKOW12AB01849C9             OneRepublic
# 4414  TRVSBTV12903CC6670  SOLFXKT12AB017E3E0      Charttraxx Karaoke
# 6078  TRRJZWL128F146D790  SOPKPSQ12A58A7A5E4     My Chemical Romance
# 968   TRQTLTB128F92F785B  SOCKSGZ12A58A7CA4B             Linkin Park
# 9932  TRNTALF128EF343800  SOZVCRW12A67ADA0B7             The Killers
# 7935  TRRNFHH128F92D262D  SOUJVIT12A8C1451C1            Rise Against
# 1125  TRENTGL128E0780C8E  SOCVTLJ12A6310F0FD                Coldplay
# 355   TRHKJNX12903CEFCDF  SOAXGDH12A8C13F8A1  Florence + The Machine
# 8567  TRIEXMF128F92FDD60  SOWCKVR12A8C142411           Kings Of Leon
# 8567  TRTEHXL128F931687B  SOWCKVR12A8C142411           Kings Of Leon
#
#                                                   title              style  \
# code
# 6562        Welcome To The Black Parade (Album Version)         Grunge_Emo
# 4714       Helena (So Long & Goodnight) (Album Version)         Grunge_Emo
# 5509                                            Secrets  Rock_Contemporary
# 4414                                          Fireflies                NaN
# 6078  I'm Not Okay (I Promise) (Live From Sessions@AOL)         Grunge_Emo
# 968                Bleed It Out [Live At Milton Keynes]                NaN
# 9932                                When You Were Young                NaN
# 7935                                             Savior               Punk
# 1125                                             Clocks       Rock_College
# 355                      Dog Days Are Over (Radio Edit)                NaN
# 8567                                       Use Somebody                NaN
# 8567                                       Use Somebody                NaN
#
#          genre
# code
# 6562  Pop_Rock
# 4714  Pop_Rock
# 5509  Pop_Rock
# 4414       NaN
# 6078  Pop_Rock
# 968        NaN
# 9932       NaN
# 7935  Pop_Rock
# 1125  Pop_Rock
# 355        NaN
# 8567  Pop_Rock
# 8567       NaN

# %% [markdown]
# ## 자카드 지수
#
# 위의 결과를 보면, [블로그](https://blog2.lucent.me/ml/music-recommender-systems-101-intro)에서와 똑같이, 유명한 곡이 유사도와 관계 없이 계속 상위권을 차지하는 문제를 볼 수 있습니다.
# 이를 약간 완화하는 방법에는 [Jaccard Index](https://en.wikipedia.org/wiki/Jaccard_index)가 있는데, 이는 단순히 교집합의 크기를 비교하는 것이 아니라,
# **(교집합의 크기) / (합집합의 크기)** 를 이용합니다. 즉, 집합의 크기로 노멀라이즈 하는 것이라고 생각해볼 수 있겠죠?
#
# 다행히 자카드 지수에 대한 쿼리 역시 교집합 행렬을 이용하면 간단하게 계산할 수 있습니다.
# 각 노래를 들어본 사람의 수를 벡터로 나타내고, 이를 행렬의 각 행에 적절히 더해주면 합집합의 크기도 간단하게! (참고: [numpy broadcasting](http://cs231n.github.io/python-numpy-tutorial/#numpy-broadcasting))

# %%
play_count_binary_per_song = play_count_binary.sum(axis=1)
play_count_binary_per_song.shape
# Out:
# (10000, 1)

# %%
all_pair_union = play_count_binary_per_song - all_pair_intersections + play_count_binary_per_song.transpose()
all_pair_union.shape
# Out:
# (10000, 10000)

# %%
all_pair_jaccard = np.array(all_pair_intersections / all_pair_union)
all_pair_jaccard.shape
# Out:
# (10000, 10000)

# %% [markdown]
# ### 자카드 지수 쿼리
#
# 아까랑 똑같습니다. 그냥 정렬하면 끝.

# %%
def query_jaccard(song_name, return_k=10):
    idx = metadata[metadata.title == song_name].song.cat.codes.values[0]
    cand = all_pair_jaccard[idx].argsort()[::-1][:return_k+1]
    cand = list(cand[cand != idx][:return_k])
    return [idx] + cand

# %%
metadata.loc[query_jaccard('You Belong With Me')]
# Out:
#                    track                song                           artist  \
# code
# 7330  TRJPXVB128F9316916  SOSROFB12AAF3B4C5D                     Taylor Swift
# 7761  TRSDRPY128F933E202  SOTWSXL12A8C143349                     Taylor Swift
# 7761  TROPUMP128F92EC162  SOTWSXL12A8C143349                     Taylor Swift
# 977   TRGMZNT128F92DE267  SOCLMAD12AB017FC09                     Taylor Swift
# 2664  TRLVQME128F931BAF3  SOGTQNI12AB0184A5C                         Owl City
# 3418  TRBTNPR12903D13765  SOISNSU12AC468C0D8                     Adam Lambert
# 2195  TRBNYBX128F422EC61  SOFRCGW12A81C21EA6                  Plain White T's
# 8691  TRLCLEM128F93402D3  SOWKQYL12AB0183B15                     Jason Derulo
# 620   TRCPAGR128F423A01A  SOBOAFP12A8C131F36      Jason Mraz & Colbie Caillat
# 5676  TRMOYCC128C7196947  SOOJJCT12A6310E1C0                     3 Doors Down
# 2634  TRMEQQX12903CCD9D5  SOGSAYQ12AB018BA14  Sean Kingston and Justin Bieber
# 4254  TRCBRTN12903CC4BD1  SOKUPAO12AB018D576                         Paramore
#
#                                    title                style     genre
# code
# 7330                  You Belong With Me  Country_Traditional   Country
# 7761                          Love Story                  NaN       NaN
# 7761                          Love Story  Country_Traditional   Country
# 977                           Tim McGraw  Country_Traditional   Country
# 2664                    Vanilla Twilight           Grunge_Emo  Pop_Rock
# 3418                        If I Had You                  NaN       NaN
# 2195                   Hey There Delilah                  NaN       NaN
# 8691                         Whatcha Say          Hip_Hop_Rap       RnB
# 620                Lucky (Album Version)                  NaN       NaN
# 5676                    Here Without You                  NaN  Pop_Rock
# 2634                        Eenie Meenie                  NaN       NaN
# 4254  The Only Exception (Album Version)                  NaN       NaN

# %% [markdown]
# **들어보기**
#
# - https://playlist.radio/en/t/TRJPXVB128F9316916/1
# - https://playlist.radio/en/t/TRLVQME128F931BAF3/2
# - https://playlist.radio/en/t/TRBTNPR12903D13765/3

# %%
metadata.loc[query_jaccard('Fix You')]
# Out:
#                    track                song                       artist  \
# code
# 8597  TRYVBMA128E0789D39  SOWEJXA12A6701C574                     Coldplay
# 4114  TRQFXKD128E0780CAE  SOKLRPJ12A8C13C3FE                     Coldplay
# 1125  TRENTGL128E0780C8E  SOCVTLJ12A6310F0FD                     Coldplay
# 6284  TRIKGRK128E0780DB0  SOPXKYD12A6D4FA876                     Coldplay
# 6284  TRTZNQZ12903CD044C  SOPXKYD12A6D4FA876                     Coldplay
# 7873  TRXWAZC128F9314B3E  SOUFPNI12A8C142D19                   John Mayer
# 620   TRCPAGR128F423A01A  SOBOAFP12A8C131F36  Jason Mraz & Colbie Caillat
# 4254  TRCBRTN12903CC4BD1  SOKUPAO12AB018D576                     Paramore
# 8567  TRIEXMF128F92FDD60  SOWCKVR12A8C142411                Kings Of Leon
# 8567  TRTEHXL128F931687B  SOWCKVR12A8C142411                Kings Of Leon
# 7755  TRKRRUV128F92F20F1  SOTWNDJ12A8C143984                        Train
# 7761  TRSDRPY128F933E202  SOTWSXL12A8C143349                 Taylor Swift
# 7761  TROPUMP128F92EC162  SOTWSXL12A8C143349                 Taylor Swift
# 4414  TRVSBTV12903CC6670  SOLFXKT12AB017E3E0           Charttraxx Karaoke
#
#                                    title                style     genre
# code
# 8597                             Fix You                  NaN       NaN
# 4114                       The Scientist     Pop_Contemporary  Pop_Rock
# 1125                              Clocks         Rock_College  Pop_Rock
# 6284                              Yellow     Pop_Contemporary  Pop_Rock
# 6284                              Yellow                  NaN       NaN
# 7873                  Heartbreak Warfare    Rock_Contemporary  Pop_Rock
# 620                Lucky (Album Version)                  NaN       NaN
# 4254  The Only Exception (Album Version)                  NaN       NaN
# 8567                        Use Somebody                  NaN  Pop_Rock
# 8567                        Use Somebody                  NaN       NaN
# 7755                            Marry Me                  NaN       NaN
# 7761                          Love Story                  NaN       NaN
# 7761                          Love Story  Country_Traditional   Country
# 4414                           Fireflies                  NaN       NaN

# %% [markdown]
# **들어보기**
#
# - https://playlist.radio/en/t/80cc0a6909/1
# - https://playlist.radio/en/t/TRCPAGR128F423A01A/2
# - https://playlist.radio/en/t/TRTEHXL128F931687B/3

# %%
metadata.loc[query_jaccard('Welcome To The Black Parade (Album Version)')]
# Out:
#                    track                song                      artist  \
# code
# 6562  TRKJHNE128F42380FC  SOQQAAQ12A67ADE34D         My Chemical Romance
# 6078  TRRJZWL128F146D790  SOPKPSQ12A58A7A5E4         My Chemical Romance
# 4714  TRYZMOC128F423E58D  SOLXXZI12A8AE4733A         My Chemical Romance
# 2583  TRHWCVS128F14895A3  SOGOZLT12A6D4FB302         My Chemical Romance
# 8774  TRWLOCY128F9338118  SOWPLVJ12AB0183586                Fall Out Boy
# 8774  TRSSSJW128F146D5DC  SOWPLVJ12AB0183586                Fall Out Boy
# 9415  TRSJBHU128F1496F3E  SOYIOZB12A58A797FC                Fall Out Boy
# 5882  TRMAFWC128F423E58F  SOOXMSN12A58A7A8D3         My Chemical Romance
# 3796  TRZIQMY128F146E70D  SOJRFWQ12AB0183582                Fall Out Boy
# 3796  TRJQKHL128F9304295  SOJRFWQ12AB0183582                Fall Out Boy
# 3796  TRYMVOW128F92ECE27  SOJRFWQ12AB0183582                Fall Out Boy
# 8086  TREFJVA128F423E591  SOUTXQX12A8AE4734A         My Chemical Romance
# 5711  TRLOMKL128F4295BDA  SOOLYZQ12A6D4FA5B7  The Red Jumpsuit Apparatus
# 9284  TRVVSIM128F423E594  SOXZEWL12A8AE47353         My Chemical Romance
#
#                                                   title       style     genre
# code
# 6562        Welcome To The Black Parade (Album Version)  Grunge_Emo  Pop_Rock
# 6078  I'm Not Okay (I Promise) (Live From Sessions@AOL)  Grunge_Emo  Pop_Rock
# 4714       Helena (So Long & Goodnight) (Album Version)  Grunge_Emo  Pop_Rock
# 2583                          Teenagers (Album Version)  Grunge_Emo  Pop_Rock
# 8774                             Sugar_ We're Goin Down         NaN       NaN
# 8774                             Sugar_ We're Goin Down         NaN       NaN
# 9415              This Ain't A Scene_ It's An Arms Race         NaN       NaN
# 5882                         To The End (Album Version)  Grunge_Emo  Pop_Rock
# 3796                                       Dance_ Dance         NaN       NaN
# 3796                                       Dance_ Dance         NaN       NaN
# 3796                                       Dance_ Dance         NaN       NaN
# 8086                   The Ghost Of You (Album Version)  Grunge_Emo  Pop_Rock
# 5711                          Face Down (Album Version)         NaN       NaN
# 9284            Thank You For The Venom (Album Version)  Grunge_Emo  Pop_Rock

# %% [markdown]
# **들어보기**
#
# - https://playlist.radio/en/t/TROBZMA12903CF2DEB/1
# - https://playlist.radio/en/t/TRWLOCY128F9338118/2
# - https://playlist.radio/en/t/TRAKBYP128F42385F0/3

# %% [markdown]
# 이제는 넓은 범위에서 봤을 때엔 비슷하다고 할 수 있는 노래가 나옵니다.
# 여전히 &lt;You Belong With Me&gt; 에서 &lt;Whatcha Say&gt; 가 나오는 등, 뜬금없는 경우가 존재하지만요.

# %% [markdown]
# ## TF-IDF
#
# [블로그](https://blog2.lucent.me/ml/music-recommender-systems-101-intro)에서 본 것 처럼, TF-IDF를 이용해서 가중치를 계산하고, 이렇게 얻은 벡터를 코사인 유사도를 이용해서 쿼리해 봅시다.

# %%
def tf_idf(matrix):
    tf = matrix.sqrt()
    idf = 1 + np.log1p(matrix.shape[-1]) - np.log1p(np.bincount(matrix.tocoo().row))
    return tf.multiply(idf.reshape(-1, 1)).tocsr()

# %%
play_count_tfidf = tf_idf(play_count_matrix)

# %%
def cosine_similarity_sparse(v1, v2):
    return v1.dot(v2.transpose())[0, 0] / np.sqrt(v1.dot(v1.transpose())[0, 0]) / np.sqrt(v2.dot(v2.transpose())[0, 0])

# %% [markdown]
# ### TF-IDF 쿼리
#
# 사실 이렇게 큰 벡터를 비교할 때에는 일일이 비교하기보다 [Approximate Nearest Neighbor](https://github.com/facebookresearch/pysparnn)를 사용하는게 상식적인 접근이지만, 우선은 그냥 해 봅시다.

# %%
def query_tfidf(song_name, return_k=10):
    idx = metadata[metadata.title == song_name].song.cat.codes.values[0]
    target = play_count_tfidf[idx]
    sim = np.array([cosine_similarity_sparse(target, play_count_tfidf[i]) for i in range(play_count_tfidf.shape[0])], dtype=np.float64)
    cand = sim.argsort()[::-1][:return_k+1]
    cand = list(cand[cand != idx][:return_k])
    return [idx] + cand

# %%
metadata.loc[query_tfidf('You Belong With Me')]
# Out:
#                    track                song                       artist  \
# code
# 7330  TRJPXVB128F9316916  SOSROFB12AAF3B4C5D                 Taylor Swift
# 7761  TRSDRPY128F933E202  SOTWSXL12A8C143349                 Taylor Swift
# 7761  TROPUMP128F92EC162  SOTWSXL12A8C143349                 Taylor Swift
# 977   TRGMZNT128F92DE267  SOCLMAD12AB017FC09                 Taylor Swift
# 5241  TRFSCMH128F425CB85  SONHLJN12A81C2169B                Mickie Krause
# 4414  TRVSBTV12903CC6670  SOLFXKT12AB017E3E0           Charttraxx Karaoke
# 6216  TROHFJK12903CC4BCE  SOPTLQL12AB018D56F                 Travie McCoy
# 8474  TRGCHLH12903CB7352  SOVWADY12AB0189C63                  Miley Cyrus
# 620   TRCPAGR128F423A01A  SOBOAFP12A8C131F36  Jason Mraz & Colbie Caillat
# 5509  TROAQBZ128F9326213  SONYKOW12AB01849C9                  OneRepublic
# 4254  TRCBRTN12903CC4BD1  SOKUPAO12AB018D576                     Paramore
# 2195  TRBNYBX128F422EC61  SOFRCGW12A81C21EA6              Plain White T's
#
#                                                   title                style  \
# code
# 7330                                 You Belong With Me  Country_Traditional
# 7761                                         Love Story                  NaN
# 7761                                         Love Story  Country_Traditional
# 977                                          Tim McGraw  Country_Traditional
# 5241          Orange Trägt Nur Die Müllabfuhr (Go West)     Pop_Contemporary
# 4414                                          Fireflies                  NaN
# 6216  Billionaire [feat. Bruno Mars]  (Explicit Albu...                  NaN
# 8474                                Party In The U.S.A.                  NaN
# 620                               Lucky (Album Version)                  NaN
# 5509                                            Secrets    Rock_Contemporary
# 4254                 The Only Exception (Album Version)                  NaN
# 2195                                  Hey There Delilah                  NaN
#
#          genre
# code
# 7330   Country
# 7761       NaN
# 7761   Country
# 977    Country
# 5241  Pop_Rock
# 4414       NaN
# 6216       NaN
# 8474  Pop_Rock
# 620        NaN
# 5509  Pop_Rock
# 4254       NaN
# 2195       NaN

# %% [markdown]
# **들어보기**
#
# - https://playlist.radio/en/t/TROBZMA12903CF2DEB/1
# - https://www.youtube.com/watch?v=ou6SJe5vBrA
# - https://playlist.radio/en/t/TROHFJK12903CC4BCE/2

# %%
metadata.loc[query_tfidf('Fix You')]
# Out:
#                    track                song                  artist  \
# code
# 8597  TRYVBMA128E0789D39  SOWEJXA12A6701C574                Coldplay
# 4114  TRQFXKD128E0780CAE  SOKLRPJ12A8C13C3FE                Coldplay
# 1125  TRENTGL128E0780C8E  SOCVTLJ12A6310F0FD                Coldplay
# 6284  TRIKGRK128E0780DB0  SOPXKYD12A6D4FA876                Coldplay
# 6284  TRTZNQZ12903CD044C  SOPXKYD12A6D4FA876                Coldplay
# 7944  TRYNYSX128E07897B3  SOUKJBT12A6701C4D6                Coldplay
# 5509  TROAQBZ128F9326213  SONYKOW12AB01849C9             OneRepublic
# 4414  TRVSBTV12903CC6670  SOLFXKT12AB017E3E0      Charttraxx Karaoke
# 8567  TRIEXMF128F92FDD60  SOWCKVR12A8C142411           Kings Of Leon
# 8567  TRTEHXL128F931687B  SOWCKVR12A8C142411           Kings Of Leon
# 7873  TRXWAZC128F9314B3E  SOUFPNI12A8C142D19              John Mayer
# 4254  TRCBRTN12903CC4BD1  SOKUPAO12AB018D576                Paramore
# 355   TRHKJNX12903CEFCDF  SOAXGDH12A8C13F8A1  Florence + The Machine
#
#                                    title              style     genre
# code
# 8597                             Fix You                NaN       NaN
# 4114                       The Scientist   Pop_Contemporary  Pop_Rock
# 1125                              Clocks       Rock_College  Pop_Rock
# 6284                              Yellow   Pop_Contemporary  Pop_Rock
# 6284                              Yellow                NaN       NaN
# 7944                      Speed Of Sound   Pop_Contemporary  Pop_Rock
# 5509                             Secrets  Rock_Contemporary  Pop_Rock
# 4414                           Fireflies                NaN       NaN
# 8567                        Use Somebody                NaN  Pop_Rock
# 8567                        Use Somebody                NaN       NaN
# 7873                  Heartbreak Warfare  Rock_Contemporary  Pop_Rock
# 4254  The Only Exception (Album Version)                NaN       NaN
# 355       Dog Days Are Over (Radio Edit)                NaN       NaN

# %% [markdown]
# **들어보기**
#
# - https://playlist.radio/en/t/80cc0a6909/1
# - https://playlist.radio/en/t/TROAQBZ128F9326213/2
# - https://playlist.radio/en/t/TRTEHXL128F931687B/3

# %%
metadata.loc[query_tfidf('Welcome To The Black Parade (Album Version)')]
# Out:
#                    track                song                      artist  \
# code
# 6562  TRKJHNE128F42380FC  SOQQAAQ12A67ADE34D         My Chemical Romance
# 6078  TRRJZWL128F146D790  SOPKPSQ12A58A7A5E4         My Chemical Romance
# 4714  TRYZMOC128F423E58D  SOLXXZI12A8AE4733A         My Chemical Romance
# 2583  TRHWCVS128F14895A3  SOGOZLT12A6D4FB302         My Chemical Romance
# 5882  TRMAFWC128F423E58F  SOOXMSN12A58A7A8D3         My Chemical Romance
# 9415  TRSJBHU128F1496F3E  SOYIOZB12A58A797FC                Fall Out Boy
# 7303  TRQFMAE128F92FA8F2  SOSPING12A58A7B4FF        Lou Reed & John Cale
# 3796  TRZIQMY128F146E70D  SOJRFWQ12AB0183582                Fall Out Boy
# 3796  TRJQKHL128F9304295  SOJRFWQ12AB0183582                Fall Out Boy
# 3796  TRYMVOW128F92ECE27  SOJRFWQ12AB0183582                Fall Out Boy
# 8396  TRIAOSK128E0785308  SOVPSKL12A670206B9              Jaci Velasquez
# 5711  TRLOMKL128F4295BDA  SOOLYZQ12A6D4FA5B7  The Red Jumpsuit Apparatus
# 7091  TRQUXPB128F147C1DA  SOSCGFN12AF729B231         My Chemical Romance
#
#                                                   title       style      genre
# code
# 6562        Welcome To The Black Parade (Album Version)  Grunge_Emo   Pop_Rock
# 6078  I'm Not Okay (I Promise) (Live From Sessions@AOL)  Grunge_Emo   Pop_Rock
# 4714       Helena (So Long & Goodnight) (Album Version)  Grunge_Emo   Pop_Rock
# 2583                          Teenagers (Album Version)  Grunge_Emo   Pop_Rock
# 5882                         To The End (Album Version)  Grunge_Emo   Pop_Rock
# 9415              This Ain't A Scene_ It's An Arms Race         NaN        NaN
# 7303                             I Believe (LP Version)         NaN        NaN
# 3796                                       Dance_ Dance         NaN        NaN
# 3796                                       Dance_ Dance         NaN        NaN
# 3796                                       Dance_ Dance         NaN        NaN
# 8396                          Something (Album Version)   Pop_Latin  Religious
# 5711                          Face Down (Album Version)         NaN        NaN
# 7091                       Vampires Will Never Hurt You         NaN        NaN

# %% [markdown]
# **들어보기**
#
# - https://playlist.radio/en/t/TROBZMA12903CF2DEB/1
# - https://www.youtube.com/watch?v=GNm5drtAQXs
# - https://www.youtube.com/watch?v=bKyNkjRumqY

# %% [markdown]
# 그야말로 총체적 난국. 처음의 문제가 그닥 완화되지 않은 채 계속 발생하고, 그로 인해 추천 퀄리티가 자카드 지수 때보다 오히려 안 좋아졌습니다.

# %% [markdown]
# ## Latent Semantic Analysis
#
# 이번에는 SVD를 이용해서 희소 행렬에 숨어있는 취향의 구조를 찾아내 봅시다.

# %%
from sklearn.decomposition import TruncatedSVD
def svd(matrix, K):
    transformer = TruncatedSVD(n_components=K, n_iter=10)
    return transformer.fit_transform(matrix)

# %%
play_count_lsa = svd(play_count_tfidf, K=50)
play_count_lsa.shape
# Out:
# (10000, 50)

# %%
def cosine_similarity_dense(v1, v2):
    return v1.dot(v2.transpose()) / np.sqrt(v1.dot(v1.transpose())) / np.sqrt(v2.dot(v2.transpose()))

# %% [markdown]
# ### LSA 쿼리
#
# 역시 이런 벡터의 경우에도 Nearest Neighbor를 쓰는게 일반적이지만, 50차원에 1만 곡 밖에 안 되니까 그냥.

# %%
def query_lsa(song_name, return_k=10):
    idx = metadata[metadata.title == song_name].song.cat.codes.values[0]
    target = play_count_lsa[idx]
    sim = np.apply_along_axis(lambda v: cosine_similarity_dense(target, v), 1, play_count_lsa)
    cand = sim.argsort()[::-1][:return_k+1]
    cand = list(cand[cand != idx][:return_k])
    return [idx] + cand

# %%
metadata.loc[query_lsa('You Belong With Me')]
# Out:
#                    track                song                    artist  \
# code
# 7330  TRJPXVB128F9316916  SOSROFB12AAF3B4C5D              Taylor Swift
# 977   TRGMZNT128F92DE267  SOCLMAD12AB017FC09              Taylor Swift
# 7761  TRSDRPY128F933E202  SOTWSXL12A8C143349              Taylor Swift
# 7761  TROPUMP128F92EC162  SOTWSXL12A8C143349              Taylor Swift
# 747   TRIUFKY12903CE6EA6  SOBWSGV12AB018B5E0  Selena Gomez & The Scene
# 2195  TRBNYBX128F422EC61  SOFRCGW12A81C21EA6           Plain White T's
# 4968  TRHCDSY128F931692E  SOMPTCI12AB017C416              Taylor Swift
# 3418  TRBTNPR12903D13765  SOISNSU12AC468C0D8              Adam Lambert
# 5241  TRFSCMH128F425CB85  SONHLJN12A81C2169B             Mickie Krause
# 6421  TRKQRVO128F92D630B  SOQGJZA12A8C1367AE                Katy Perry
# 1227  TRFGWOW12903CF14C3  SODCADR12AF72A1A99              Adam Lambert
# 8105  TRVEKLH128F92DE271  SOUVGJL12AB017FC35              Taylor Swift
#
#                                           title                style     genre
# code
# 7330                         You Belong With Me  Country_Traditional   Country
# 977                                  Tim McGraw  Country_Traditional   Country
# 7761                                 Love Story                  NaN       NaN
# 7761                                 Love Story  Country_Traditional   Country
# 747                                   Naturally                  NaN       NaN
# 2195                          Hey There Delilah                  NaN       NaN
# 4968                           Forever & Always  Country_Traditional   Country
# 3418                               If I Had You                  NaN       NaN
# 5241  Orange Trägt Nur Die Müllabfuhr (Go West)     Pop_Contemporary  Pop_Rock
# 6421                            Thinking Of You                  NaN       NaN
# 1227                       Whataya Want From Me                  NaN  Pop_Rock
# 8105                                   Our Song  Country_Traditional   Country

# %% [markdown]
# **들어보기**
#
# - https://playlist.radio/en/t/TRJPXVB128F9316916/1
# - https://playlist.radio/en/t/TRIUFKY12903CE6EA6/2
# - https://playlist.radio/en/t/TRKQRVO128F92D630B/3

# %%
metadata.loc[query_lsa('Fix You')]
# Out:
#                    track                song         artist  \
# code
# 8597  TRYVBMA128E0789D39  SOWEJXA12A6701C574       Coldplay
# 4114  TRQFXKD128E0780CAE  SOKLRPJ12A8C13C3FE       Coldplay
# 1125  TRENTGL128E0780C8E  SOCVTLJ12A6310F0FD       Coldplay
# 6284  TRIKGRK128E0780DB0  SOPXKYD12A6D4FA876       Coldplay
# 6284  TRTZNQZ12903CD044C  SOPXKYD12A6D4FA876       Coldplay
# 7944  TRYNYSX128E07897B3  SOUKJBT12A6701C4D6       Coldplay
# 4486  TRNGAAK128F147DF92  SOLJWIQ12A6D4FA875       Coldplay
# 8567  TRIEXMF128F92FDD60  SOWCKVR12A8C142411  Kings Of Leon
# 8567  TRTEHXL128F931687B  SOWCKVR12A8C142411  Kings Of Leon
# 5509  TROAQBZ128F9326213  SONYKOW12AB01849C9    OneRepublic
# 9176  TRAALAH128E078234A  SOXQYSC12A6310E908      The Verve
# 4695  TRKBJPL12903CED195  SOLWZVR12AB01849C6    OneRepublic
# 6176  TROTIUH128E0782538  SOPQLBY12A6310E992      Radiohead
#
#                       title              style     genre
# code
# 8597                Fix You                NaN       NaN
# 4114          The Scientist   Pop_Contemporary  Pop_Rock
# 1125                 Clocks       Rock_College  Pop_Rock
# 6284                 Yellow   Pop_Contemporary  Pop_Rock
# 6284                 Yellow                NaN       NaN
# 7944         Speed Of Sound   Pop_Contemporary  Pop_Rock
# 4486                 Sparks   Pop_Contemporary  Pop_Rock
# 8567           Use Somebody                NaN  Pop_Rock
# 8567           Use Somebody                NaN       NaN
# 5509                Secrets  Rock_Contemporary  Pop_Rock
# 9176  Bitter Sweet Symphony   Pop_Contemporary  Pop_Rock
# 4695    All The Right Moves  Rock_Contemporary  Pop_Rock
# 6176       Creep (Explicit)   Pop_Contemporary  Pop_Rock

# %% [markdown]
# **들어보기**
#
# - https://playlist.radio/en/t/80cc0a6909/1
# - https://playlist.radio/en/t/TRAALAH128E078234A/2
# - https://www.youtube.com/watch?v=lZiNtbgm9oM

# %%
metadata.loc[query_lsa('Welcome To The Black Parade (Album Version)')]
# Out:
#                    track                song               artist  \
# code
# 6562  TRKJHNE128F42380FC  SOQQAAQ12A67ADE34D  My Chemical Romance
# 2583  TRHWCVS128F14895A3  SOGOZLT12A6D4FB302  My Chemical Romance
# 3796  TRZIQMY128F146E70D  SOJRFWQ12AB0183582         Fall Out Boy
# 3796  TRJQKHL128F9304295  SOJRFWQ12AB0183582         Fall Out Boy
# 3796  TRYMVOW128F92ECE27  SOJRFWQ12AB0183582         Fall Out Boy
# 6078  TRRJZWL128F146D790  SOPKPSQ12A58A7A5E4  My Chemical Romance
# 9595  TRUNAXR128F93119C6  SOYWRLV12AB0186090   Panic At The Disco
# 8774  TRWLOCY128F9338118  SOWPLVJ12AB0183586         Fall Out Boy
# 8774  TRSSSJW128F146D5DC  SOWPLVJ12AB0183586         Fall Out Boy
# 9415  TRSJBHU128F1496F3E  SOYIOZB12A58A797FC         Fall Out Boy
# 8396  TRIAOSK128E0785308  SOVPSKL12A670206B9       Jaci Velasquez
# 4714  TRYZMOC128F423E58D  SOLXXZI12A8AE4733A  My Chemical Romance
# 4480  TRXVBBR128F92E26C8  SOLJPFF12A8C133221   Panic At The Disco
# 9935  TRQHUZE128F42385E8  SOZVMYF12A8C132646         Fall Out Boy
#
#                                                   title       style      genre
# code
# 6562        Welcome To The Black Parade (Album Version)  Grunge_Emo   Pop_Rock
# 2583                          Teenagers (Album Version)  Grunge_Emo   Pop_Rock
# 3796                                       Dance_ Dance         NaN        NaN
# 3796                                       Dance_ Dance         NaN        NaN
# 3796                                       Dance_ Dance         NaN        NaN
# 6078  I'm Not Okay (I Promise) (Live From Sessions@AOL)  Grunge_Emo   Pop_Rock
# 9595       I Write Sins Not Tragedies [Live In Chicago]         NaN        NaN
# 8774                             Sugar_ We're Goin Down         NaN        NaN
# 8774                             Sugar_ We're Goin Down         NaN        NaN
# 9415              This Ain't A Scene_ It's An Arms Race         NaN        NaN
# 8396                          Something (Album Version)   Pop_Latin  Religious
# 4714       Helena (So Long & Goodnight) (Album Version)  Grunge_Emo   Pop_Rock
# 4480              Nine In The Afternoon (Album Version)  Grunge_Emo   Pop_Rock
# 9935                                            Beat It         NaN        NaN

# %% [markdown]
# **들어보기**
#
# - https://playlist.radio/en/t/TROBZMA12903CF2DEB/1
# - https://www.youtube.com/watch?v=lrFLekQ2lMU
# - https://playlist.radio/en/t/TRIAOSK128E0785308/3

# %% [markdown]
# 자카드 지수나 TF-IDF와 비슷한 것 같지만, &lt;You Belong To Me&gt;의 경우에는 케이티 페리나 셀레나 고메즈가 나온걸 보아 많이 좋아진 것을 확인할 수 있습니다!! 다만, 여전히 나머지 두 곡의 결과는 골때리는 문제를 보여주고 있습니다.
# 다음 포스팅과 노트북에서는 이런 부분을 해결할 수 있는 다른 방법에 대해 알아봅시다.
